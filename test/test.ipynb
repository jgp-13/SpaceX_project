# %%
import pandas as pd
import numpy as np
import os
import space_x
import pickle

from space_x.config import INTERIM_DATA_DIR

# %%
csv4 = pd.read_csv(os.path.join(INTERIM_DATA_DIR,'Spacex.csv'))
csv3 = pd.read_csv(os.path.join(INTERIM_DATA_DIR,'dataset_part_2.csv'))
csv1 = pd.read_csv(os.path.join(INTERIM_DATA_DIR,'dataset_part_1.csv'))
csv2 = os.path.join(INTERIM_DATA_DIR,'spacex_web_scraped.csv')

# %%
csv3.sample(5)
# Out:
#     FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 63            64  2019-05-04       Falcon 9       2482.0   ISS  CCSFS SLC 40
# 86            87  2020-10-06       Falcon 9      15600.0  VLEO    KSC LC 39A
# 3              4  2013-09-29       Falcon 9        500.0    PO   VAFB SLC 4E
# 89            90  2020-11-05       Falcon 9       3681.0   MEO  CCSFS SLC 40
# 49            50  2018-05-11       Falcon 9       3750.0   GTO    KSC LC 39A
#
#         Outcome  Flights  GridFins  Reused   Legs                LandingPad  \
# 63    True ASDS        1      True   False   True  5e9e3032383ecb6bb234e7ca
# 86    True ASDS        3      True    True   True  5e9e3032383ecb6bb234e7ca
# 3   False Ocean        1     False   False  False                       NaN
# 89    True ASDS        1      True   False   True  5e9e3032383ecb6bb234e7ca
# 49    True ASDS        1      True   False   True  5e9e3032383ecb6bb234e7ca
#
# ...

# %%
csv1['Customer'].unique()
# Out:
# array(['SpaceX', 'NASA(COTS)', 'NASA (CRS)', 'MDA', 'SES', 'Thaicom',
#        'Orbcomm', 'AsiaSat', 'NASA', 'Turkmenistan National Space Agency',
#        'SKY Perfect JSAT Group', 'SKY Perfect JCSAT Group', 'Spacecom',
#        'Iridium Communications', 'EchoStar', 'NRO', 'Inmarsat',
#        'Bulgaria Sat', 'Intelsat', 'NSPO (Taiwan)', 'USAF',
#        'KT Corporation', 'Northrop Grumman', 'GovSat', 'Hispasat',
#        'Bangladesh Gov', 'Telesat', 'Telkom', 'CONAE', 'Es’hailSat',
#        'Spaceflight Industries, Inc', 'NASA (CCtCap)', 'CSA',
#        'SKY Perfect JSAT Corporation', 'South Korea',
#        'United States Space Force'], dtype=object)

# %%
csv4['Mission_Outcome'].unique()
# Out:
# array(['Success', 'Failure (in flight)',
#        'Success (payload status unclear)', 'Success '], dtype=object)

# %%
csv4[csv4['Mission_Outcome']=='Success (payload status unclear)']
# Out:
#           Date Time (UTC) Booster_Version   Launch_Site Payload  \
# 46  2018-01-08    1:00:00   F9 B4 B1043.1  CCAFS SLC-40    Zuma
#
#     PAYLOAD_MASS__KG_ Orbit          Customer  \
# 46               5000   LEO  Northrop Grumman
#
#                      Mission_Outcome       Landing_Outcome
# 46  Success (payload status unclear)  Success (ground pad)
