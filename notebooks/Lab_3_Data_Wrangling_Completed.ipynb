# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Data wrangling

# %% [markdown]
# In this lab, some Exploratory Data Analysis (EDA) will be performed in order to identify patterns within the data and determine the appropriate label for training supervised models.
#
# Within the data set, several instances in which the booster did not land successfully are observed. In some cases, a landing was attempted but ultimately failed due to an accident. For example, the indicator <code>True Ocean</code> signifies that the mission outcome involved a successful landing in a specific region of the ocean, whereas <code>False Ocean</code> signifies an unsuccessful landing in the same region. Similarly, <code>True RTLS</code> indicates that the mission outcome involved a successful landing on a ground pad, while <code>False RTLS</code> indicates an unsuccessful landing on a ground pad. Likewise, <code>True ASDS</code> indicates that the mission outcome involved a successful landing on a drone ship, whereas <code>False ASDS</code> indicates an unsuccessful landing on a drone ship.
#
# In this lab, these outcomes are primarily converted into training labels, where a value of `1` signifies that the booster landed successfully, and a value of `0` signifies that it did not.
#
# The Falcon 9 first stage is expected to land successfully.

# %% [markdown]
# ![](./images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](./images/crash.gif)

# %% [markdown]
# ## Objectives
#
# Exploratory data analysis was carried out, and training labels were determined.
#
# * Exploratory data analysis was conducted.
# * Training labels were established.

# %% [markdown]
# ***

# %%
import pandas as pd
import numpy as np
import os
import space_x
import pickle

from space_x.config import INTERIM_DATA_DIR

pd.set_option('display.max_columns', None)    # Setting this option will print all collumns of a dataframe
pd.set_option('display.max_colwidth', None)   # Setting this option will print all of the data in a feature

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Merging data

# %% [markdown]
# Space X datasets, are downloaded from previous sections.

# %%
csv_file = os.path.join(INTERIM_DATA_DIR, 'spacex_web_scraped.csv')
df2 = pd.read_csv(csv_file)
print(len(df2))
display(df2.head())
df2.info()
# Out:
# 121
#    Flight_Number Launch_Site                               Payload  \
# 0              1       CCAFS  Dragon Spacecraft Qualification Unit
# 1              2       CCAFS                                Dragon
# 2              3       CCAFS                                Dragon
# 3              4       CCAFS                          SpaceX CRS-1
# 4              5       CCAFS                          SpaceX CRS-2
#
#   Payload_Mass Orbit Customer Launch_Outcome   Booster_Version  \
# 0            0   LEO   SpaceX        Success  F9 v1.07B0003.18
# 1            0   LEO     NASA        Success  F9 v1.07B0004.18
# 2       525 kg   LEO     NASA        Success  F9 v1.07B0005.18
# 3     4,700 kg   LEO     NASA        Success  F9 v1.07B0006.18
# 4     4,877 kg   LEO     NASA        Success  F9 v1.07B0007.18
#
#   Booster_Landing             Date   Time
# 0         Failure      4 June 2010  18:45
# 1         Failure  8 December 2010  15:43
# 2      No attempt      22 May 2012  07:44
# 3      No attempt   8 October 2012  00:35
# 4      No attempt     1 March 2013  15:10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Flight_Number    121 non-null    int64
#  1   Launch_Site      121 non-null    object
#  2   Payload          121 non-null    object
#  3   Payload_Mass     121 non-null    object
#  4   Orbit            121 non-null    object
#  5   Customer         120 non-null    object
#  6   Launch_Outcome   121 non-null    object
#  7   Booster_Version  121 non-null    object
#  8   Booster_Landing  121 non-null    object
#  9   Date             121 non-null    object
#  10  Time             121 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 10.5+ KB

# %%
pickle_file = os.path.join(INTERIM_DATA_DIR, 'dataset_part_1.pkl')
with open(pickle_file, 'rb') as file:
    df1 = pickle.load(file)
print(len(df1))
display(df1.head())
df1.info()
# Out:
# 90
#    Flight_Number                  date_utc        Date      Time  \
# 4              1 2010-06-04 18:45:00+00:00  2010-06-04  18:45:00
# 5              2 2012-05-22 07:44:00+00:00  2012-05-22  07:44:00
# 6              3 2013-03-01 19:10:00+00:00  2013-03-01  19:10:00
# 7              4 2013-09-29 16:00:00+00:00  2013-09-29  16:00:00
# 8              5 2013-12-03 22:41:00+00:00  2013-12-03  22:41:00
#
#   Booster_Version  Payload_Mass Orbit   Launch_Site Mission_Outcome  Flights  \
# 4        Falcon 9   6123.547647   LEO  CCSFS SLC 40       None None        1
# 5        Falcon 9    525.000000   LEO  CCSFS SLC 40       None None        1
# 6        Falcon 9    677.000000   ISS  CCSFS SLC 40       None None        1
# 7        Falcon 9    500.000000    PO   VAFB SLC 4E     False Ocean        1
# 8        Falcon 9   3170.000000   GTO  CCSFS SLC 40       None None        1
#
#    GridFins  Reused   Legs    Customer Landing_Pad  Block  Reused_Count  \
# 4     False   False  False      SpaceX        None    1.0             0
# 5     False   False  False  NASA(COTS)        None    1.0             0
# 6     False   False  False  NASA (CRS)        None    1.0             0
# 7     False   False  False         MDA        None    1.0             0
# 8     False   False  False         SES        None    1.0             0
#
#   Serial   Longitude   Latitude
# 4  B0003  -80.577366  28.561857
# 5  B0005  -80.577366  28.561857
# 6  B0007  -80.577366  28.561857
# 7  B1003 -120.610829  34.632093
# 8  B1004  -80.577366  28.561857
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 4 to 93
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Flight_Number    90 non-null     int64
#  1   date_utc         90 non-null     datetime64[ns, UTC]
#  2   Date             90 non-null     object
#  3   Time             90 non-null     object
#  4   Booster_Version  90 non-null     object
#  5   Payload_Mass     90 non-null     float64
#  6   Orbit            90 non-null     object
#  7   Launch_Site      90 non-null     object
#  8   Mission_Outcome  90 non-null     object
#  9   Flights          90 non-null     int64
#  10  GridFins         90 non-null     bool
#  11  Reused           90 non-null     bool
#  12  Legs             90 non-null     bool
#  13  Customer         90 non-null     object
#  14  Landing_Pad      64 non-null     object
#  15  Block            90 non-null     float64
#  16  Reused_Count     90 non-null     int64
#  17  Serial           90 non-null     object
#  18  Longitude        90 non-null     float64
#  19  Latitude         90 non-null     float64
# dtypes: bool(3), datetime64[ns, UTC](1), float64(4), int64(3), object(9)
# memory usage: 12.9+ KB

# %% [markdown]
# Now both datasets will be merged

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df2['Date'] = pd.to_datetime(df2['Date'])

print(f'In the first Dataset there are {df1["Date"].duplicated().sum()} launches on the same day (duplicated values).')
print(f'In the second Dataset there are {df2["Date"].duplicated().sum()} launches on the same day (duplicated values).')
# Out:
# In the first Dataset there are 0 launches on the same day (duplicated values).
# In the second Dataset there are 0 launches on the same day (duplicated values).

# %% [markdown]
# With no duplicated values the two datasets can be merged on the launch date **`'Date'`**

# %%
df = pd.merge(df1,df2, on = 'Date', how='right')
df = df[sorted(df.columns)]
df.sample(10)
# Out:
#      Block Booster_Landing Booster_Version_x Booster_Version_y  \
# 6      1.0      No attempt          Falcon 9           F9 v1.1
# 73     5.0      No attempt          Falcon 9   F9 B5B1047.3472
# 103    NaN         Success               NaN             F9 B5
# 93     5.0         Success          Falcon 9   F9 B5B1058.3565
# 88     5.0         Success          Falcon 9   F9 B5B1058.2544
# 4      1.0      No attempt          Falcon 9  F9 v1.07B0007.18
# 41     4.0         Success          Falcon 9            F9 B4[
# 50     4.0      No attempt          Falcon 9   F9 B4B1041.2268
# 16     1.0         Failure          Falcon 9          F9 v1.1[
# 15     NaN      No attempt               NaN          F9 v1.1[
#
#                  Customer_x              Customer_y       Date  \
# 6                       SES                     SES 2013-12-03
# 73                 Spacecom                Spacecom 2019-08-06
# 103                     NaN                 Türksat 2021-01-08
# 93                   SpaceX                  SpaceX 2020-10-06
# 88              South Korea  Republic of Korea Army 2020-07-20
# 4                NASA (CRS)                    NASA 2013-03-01
# 41   Iridium Communications  Iridium Communications 2017-10-09
# 50   Iridium Communications  Iridium Communications 2018-03-30
# 16               NASA (CRS)                    NASA 2015-04-14
# 15                      NaN                     ABS 2015-03-02
#
#      Flight_Number_x  Flight_Number_y  Flights GridFins  \
# 6                5.0                7      1.0    False
# 73              68.0               74      3.0    False
# 103              NaN              104      NaN      NaN
# 93              87.0               94      3.0     True
# 88              83.0               89      2.0     True
# 4                3.0                5      1.0    False
# 41              39.0               42      1.0     True
# 50              47.0               51      2.0     True
# 16              14.0               17      1.0     True
# 15               NaN               16      NaN      NaN
#
#                   Landing_Pad   Latitude Launch_Outcome Launch_Site_x  \
# 6                        None  28.561857        Success  CCSFS SLC 40
# 73                       None  28.561857        Success  CCSFS SLC 40
# 103                       NaN        NaN        Success           NaN
# 93   5e9e3032383ecb6bb234e7ca  28.608058        Success    KSC LC 39A
# 88   5e9e3033383ecbb9e534e7cc  28.561857        Success  CCSFS SLC 40
# 4                        None  28.561857        Success  CCSFS SLC 40
# 41   5e9e3033383ecbb9e534e7cc  34.632093        Success   VAFB SLC 4E
# 50                       None  34.632093        Success   VAFB SLC 4E
# 16   5e9e3032383ecb761634e7cb  28.561857        Success  CCSFS SLC 40
# 15                        NaN        NaN        Success           NaN
#
#       Launch_Site_y   Legs   Longitude Mission_Outcome Orbit_x Orbit_y  \
# 6             CCAFS  False  -80.577366       None None     GTO     GTO
# 73            CCAFS  False  -80.577366       None None     GTO     GTO
# 103           CCSFS    NaN         NaN             NaN     NaN     GTO
# 93              KSC   True  -80.603956       True ASDS    VLEO     LEO
# 88            CCAFS   True  -80.577366       True ASDS     GEO     GTO
# 4             CCAFS  False  -80.577366       None None     ISS     LEO
# 41             VAFB   True -120.610829       True ASDS      PO   Polar
# 50             VAFB   True -120.610829       None None      PO   Polar
# 16   Cape Canaveral   True  -80.577366      False ASDS     ISS     LEO
# 15   Cape Canaveral    NaN         NaN             NaN     NaN     GTO
#
#           Payload  Payload_Mass_x  Payload_Mass_y Reused  Reused_Count Serial  \
# 6           SES-8     3170.000000        3,170 kg  False           0.0  B1004
# 73        AMOS-17     6500.000000        6,500 kg   True           2.0  B1047
# 103    Türksat 5A             NaN        3,500 kg    NaN           NaN    NaN
# 93       Starlink    15600.000000       15,600 kg   True          13.0  B1058
# 88      ANASIS-II     6123.547647  5,000–6,000 kg   True          13.0  B1058
# 4    SpaceX CRS-2      677.000000        4,877 kg  False           0.0  B0007
# 41   Iridium NEXT     9600.000000        9,600 kg  False           1.0  B1041
# 50   Iridium NEXT     9600.000000        9,600 kg   True           1.0  B1041
# 16   SpaceX CRS-6     1898.000000        1,898 kg  False           0.0  B1015
# 15         ABS-3A             NaN        4,159 kg    NaN           NaN    NaN
#
#        Time_x    Time_y                  date_utc
# 6    22:41:00     22:41 2013-12-03 22:41:00+00:00
# 73   22:52:00     23:23 2019-08-06 22:52:00+00:00
# 103       NaN     02:15                       NaT
# 93   11:29:00  11:29:34 2020-10-06 11:29:00+00:00
# 88   21:30:00     21:30 2020-07-20 21:30:00+00:00
# 4    19:10:00     15:10 2013-03-01 19:10:00+00:00
# 41   12:37:00     12:37 2017-10-09 12:37:00+00:00
# 50   14:13:51     14:14 2018-03-30 14:13:51+00:00
# 16   20:10:00     20:10 2015-04-14 20:10:00+00:00
# 15        NaN     03:50                       NaT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Block              89 non-null     float64
#  1   Booster_Landing    121 non-null    object
#  2   Booster_Version_x  89 non-null     object
#  3   Booster_Version_y  121 non-null    object
#  4   Customer_x         89 non-null     object
#  5   Customer_y         120 non-null    object
#  6   Date               121 non-null    datetime64[ns]
#  7   Flight_Number_x    89 non-null     float64
#  8   Flight_Number_y    121 non-null    int64
#  9   Flights            89 non-null     float64
#  10  GridFins           89 non-null     object
#  11  Landing_Pad        63 non-null     object
#  12  Latitude           89 non-null     float64
#  13  Launch_Outcome     121 non-null    object
#  14  Launch_Site_x      89 non-null     object
#  15  Launch_Site_y      121 non-null    object
#  16  Legs               89 non-null     object
#  17  Longitude          89 non-null     float64
#  18  Mission_Outcome    89 non-null     object
#  19  Orbit_x            89 non-null     object
#  20  Orbit_y            121 non-null    object
#  21  Payload            121 non-null    object
#  22  Payload_Mass_x     89 non-null     float64
#  23  Payload_Mass_y     121 non-null    object
#  24  Reused             89 non-null     object
#  25  Reused_Count       89 non-null     float64
#  26  Serial             89 non-null     object
#  27  Time_x             89 non-null     object
#  28  Time_y             121 non-null    object
#  29  date_utc           89 non-null     datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(7), int64(1), object(20)
# memory usage: 28.5+ KB

# %%
df[[ 'Booster_Version_x', 'Booster_Version_y', 'Serial', 'Customer_x','Customer_y', 'Flight_Number_x', 'Flight_Number_y']].sample(10)
# Out:
#     Booster_Version_x Booster_Version_y Serial                 Customer_x  \
# 9            Falcon 9           F9 v1.1  B1007                    Orbcomm
# 54                NaN   F9 B4B1043.2322    NaN                        NaN
# 72           Falcon 9   F9 B5B1056.2465  B1056                 NASA (CRS)
# 33           Falcon 9            F9 FT[  B1034                   Inmarsat
# 40           Falcon 9            F9 B4[  B1040                       USAF
# 117               NaN   F9 B5B1058.8660    NaN                        NaN
# 96           Falcon 9             F9 B5  B1062  United States Space Force
# 50           Falcon 9   F9 B4B1041.2268  B1041     Iridium Communications
# 85           Falcon 9             F9 B5  B1049                     SpaceX
# 69           Falcon 9            F9 B5[  B1056                 NASA (CRS)
#
#                  Customer_y  Flight_Number_x  Flight_Number_y
# 9                   Orbcomm              8.0               10
# 54   Iridium Communications              NaN               55
# 72                     NASA             67.0               73
# 33                 Inmarsat             31.0               34
# 40                     USAF             38.0               41
# 117                  SpaceX              NaN              118
# 96                     USSF             90.0               97
# 50   Iridium Communications             47.0               51
# 85                   SpaceX             80.0               86
# 69                     NASA             64.0               70

# %%
df[['Launch_Site_x', 'Launch_Site_x', 'Orbit_x', 'Orbit_y','Payload_Mass_x','Payload_Mass_x','Time_x','Time_y']].sample(10)
# Out:
#    Launch_Site_x Launch_Site_x Orbit_x Orbit_y  Payload_Mass_x  \
# 79  CCSFS SLC 40  CCSFS SLC 40    VLEO     LEO    15600.000000
# 62    KSC LC 39A    KSC LC 39A     GTO     GTO     3000.000000
# 88  CCSFS SLC 40  CCSFS SLC 40     GEO     GTO     6123.547647
# 38    KSC LC 39A    KSC LC 39A     ISS     LEO     2910.000000
# 31    KSC LC 39A    KSC LC 39A     GTO     GTO     5300.000000
# 63   VAFB SLC 4E   VAFB SLC 4E     SSO     SSO     4000.000000
# 35    KSC LC 39A    KSC LC 39A     GTO     GTO     3669.000000
# 47  CCSFS SLC 40  CCSFS SLC 40     GTO     GTO     4230.000000
# 44  CCSFS SLC 40  CCSFS SLC 40     ISS     LEO     2205.000000
# 11  CCSFS SLC 40  CCSFS SLC 40     GTO     GTO     4428.000000
#
#     Payload_Mass_x    Time_x    Time_y
# 79    15600.000000  14:06:00     14:07
# 62     3000.000000  20:46:00     20:46
# 88     6123.547647  21:30:00     21:30
# 38     2910.000000  16:31:00     16:31
# 31     5300.000000  22:27:00     22:27
# 63     4000.000000  18:34:00  18:34:05
# 35     3669.000000  19:10:00     19:10
# 47     4230.000000  21:25:00     21:25
# 44     2205.000000  15:36:00     15:36
# 11     4428.000000  05:00:00     05:00

# %%
df['Booster_Version'] = df['Booster_Version_x'].where(df['Booster_Version_x'].notna(), df['Booster_Version_y'])
df.drop(['Booster_Version_x','Booster_Version_y'],axis=1, inplace=True)

# %%
df['Customer'] = df['Customer_x'].where(df['Customer_x'].notna(), df['Customer_y'])
df.drop(['Customer_x','Customer_y'],axis=1, inplace=True)

# %%
df['Orbit'] = df['Orbit_x'].where(df['Orbit_x'].notna(), df['Orbit_y'])
df.drop(['Orbit_x','Orbit_y'],axis=1, inplace=True)

# %%
df['Payload_Mass'] = df['Payload_Mass_x'].where(df['Payload_Mass_x'].notna(), df['Payload_Mass_y'])
df.drop(['Payload_Mass_x','Payload_Mass_y'],axis=1, inplace=True)

# %%
df['Time_x'] = pd.to_datetime(df['Time_x'],  errors='coerce')
df['Time_y'] = pd.to_datetime(df['Time_y'],  errors='coerce')

df['Time (UTC)'] = df['Time_x'].where(df['Time_x'].notna(), df['Time_y'])
df.drop(['Time_x','Time_y'],axis=1, inplace=True)
# Out:
# C:\Users\josue\AppData\Local\Temp\ipykernel_26332\3141842105.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time_y'] = pd.to_datetime(df['Time_y'],  errors='coerce')

# %%
# Combine 'Launch_Site_x' and 'Launch_Site_y' into one column.
df['Launch_Site'] = df['Launch_Site_x'].where(df['Launch_Site_x'].notna(), df['Launch_Site_y'])

# Drop the now redundant columns as they are no longer needed.
df.drop(['Launch_Site_x', 'Launch_Site_y'], axis=1, inplace=True)

# Define a mapping dictionary to standardise the launch site names.
# This converts various designations to a consistent format.
mapping = {
    'CCAFS': 'CCSFS SLC 40',         
    'Cape Canaveral': 'CCSFS SLC 40',  
    'CCSFS': 'CCSFS SLC 40',           
    'VAFB': 'VAFB SLC 4E',             
    'KSC': 'KSC LC 39A'                
}

# Apply the mapping to update values in the 'Launch_Site' column.
df['Launch_Site'] = df['Launch_Site'].replace(mapping)

# Use a regular expression to replace the second space with a hyphen.
df['Launch_Site'] = df['Launch_Site'].str.replace(r'^(\S+ \S+) (\S+)$', r'\1-\2', regex=True)

# Split the formatted 'Launch_Site' into two new columns: 'Facility' and 'Complex'.
df[['Facility', 'Complex']] = df['Launch_Site'].str.split(' ', expand=True)

# %%
df['Flight_Number'] = df['Flight_Number_y']
df.drop(['Flight_Number_x','Flight_Number_y'],axis=1, inplace=True)

# %% [markdown]
# The percentage of missing values in each attribute was identified and calculated.

# %%
df.isnull().sum()/df.count()*100
# Out:
# Block              35.955056
# Booster_Landing     0.000000
# Date                0.000000
# Flights            35.955056
# GridFins           35.955056
# Landing_Pad        92.063492
# Latitude           35.955056
# Launch_Outcome      0.000000
# Legs               35.955056
# Longitude          35.955056
# Mission_Outcome    35.955056
# Payload             0.000000
# Reused             35.955056
# Reused_Count       35.955056
# Serial             35.955056
# date_utc           35.955056
# Booster_Version     0.000000
# Customer            0.000000
# Orbit               0.000000
# Payload_Mass        0.000000
# Time (UTC)          0.000000
# Launch_Site         0.000000
# Facility            0.000000
# Complex             0.000000
# Flight_Number       0.000000
# dtype: float64

# %% [markdown]
# Identify which columns are numerical and categorical:

# %%
df.dtypes
# Out:
# Block                          float64
# Booster_Landing                 object
# Date                    datetime64[ns]
# Flights                        float64
# GridFins                        object
# Landing_Pad                     object
# Latitude                       float64
# Launch_Outcome                  object
# Legs                            object
# Longitude                      float64
# Mission_Outcome                 object
# Payload                         object
# Reused                          object
# Reused_Count                   float64
# Serial                          object
# date_utc           datetime64[ns, UTC]
# Booster_Version                 object
# Customer                        object
# Orbit                           object
# Payload_Mass                    object
# Time (UTC)              datetime64[ns]
# Launch_Site                     object
# Facility                        object
# Complex                         object
# Flight_Number                    int64
# dtype: object

# %% [markdown]
# ### TASK 1: Calculation of the number of launches on each site
#
# The dataset comprises several SpaceX launch facilities, including:
# - <a href='https://en.wikipedia.org/wiki/List_of_Cape_Canaveral_and_Merritt_Island_launch_sites?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01'>**Cape Canaveral Space**</a> (CCSC), Launch Complex 40 (LC-40), **CCSC LC-40**
# - **Vandenberg Air Force Base Space** (VAFB), Launch Complex 4E (SLC-4E), <b>VAFB SLC-4E </b>
# - **Kennedy Space Center** (KSC), Launch Complex 39A (LC-39A), <b>KSC LC-39A </b>.
#
# The location of each launch is recorded in the `Launch_Site` column.
#
#
# Subsequently, the number of launches for each site shall be determined.
#
# The method <code>value_counts()</code> is to be utilised on the <code>LaunchSite</code> column, thereby ascertaining the number of launches per site:

# %%
# Apply value_counts() on column Launch_Site
df['Launch_Site'].value_counts()
# Out:
# Launch_Site
# CCSFS SLC-40    72
# KSC LC-39A      33
# VAFB SLC-4E     16
# Name: count, dtype: int64

# %% [markdown]
# Each launch aims to an dedicated orbit, and here are some common orbit types:

# %% [markdown]
# ### TASK 2: Calculation of the number and occurrence of each orbit

# %% [markdown]
# *   <b>LEO</b>: Low Earth orbit (LEO)is an Earth-centred orbit with an altitude of 2,000 km (1,200 mi) or less (approximately one-third of the radius of Earth),\[1] or with at least 11.25 periods per day (an orbital period of 128 minutes or less) and an eccentricity less than 0.25.\[2] Most of the manmade objects in outer space are in LEO <a href='https://en.wikipedia.org/wiki/Low_Earth_orbit?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01'>\[1]</a>.
#
# *   <b>VLEO</b>: Very Low Earth Orbits (VLEO) can be defined as the orbits with a mean altitude below 450 km. Operating in these orbits can provide a number of benefits to Earth observation spacecraft as the spacecraft operates closer to the observation<a href='https://www.researchgate.net/publication/271499606_Very_Low_Earth_Orbit_mission_concepts_for_Earth_Observation_Benefits_and_challenges?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01'>\[2]</a>.
#
# *   <b>GTO</b> A geosynchronous orbit is a high Earth orbit that allows satellites to match Earth's rotation. Located at 22,236 miles (35,786 kilometers) above Earth's equator, this position is a valuable spot for monitoring weather, communications and surveillance. Because the satellite orbits at the same speed that the Earth is turning, the satellite seems to stay in place over a single longitude, though it may drift north to south,” NASA wrote on its Earth Observatory website <a  href="https://www.space.com/29222-geosynchronous-orbit.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" >\[3] </a>.
#
# *   <b>SSO (or SO)</b>: It is a Sun-synchronous orbit  also called a heliosynchronous orbit is a nearly polar orbit around a planet, in which the satellite passes over any given point of the planet's surface at the same local mean solar time <a href="https://en.wikipedia.org/wiki/Sun-synchronous_orbit?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">\[4] <a>.
#
# *   <b>ES-L1 </b>:At the Lagrange points the gravitational forces of the two large bodies cancel out in such a way that a small object placed in orbit there is in equilibrium relative to the center of mass of the large bodies. L1 is one such point between the sun and the earth <a href="https://en.wikipedia.org/wiki/Lagrange_point?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01#L1_point">\[5]</a> .
#
# *   <b>HEO</b> A highly elliptical orbit, is an elliptic orbit with high eccentricity, usually referring to one around Earth <a href="https://en.wikipedia.org/wiki/Highly_elliptical_orbit?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">\[6]</a>.
#
# *   <b> ISS </b> A modular space station (habitable artificial satellite) in low Earth orbit. It is a multinational collaborative project between five participating space agencies: NASA (United States), Roscosmos (Russia), JAXA (Japan), ESA (Europe), and CSA (Canada)<a href="https://en.wikipedia.org/wiki/International_Space_Station?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01"> \[7] </a>
#
# *   <b> MEO </b> Geocentric orbits ranging in altitude from 2,000 km (1,200 mi) to just below geosynchronous orbit at 35,786 kilometers (22,236 mi). Also known as an intermediate circular orbit. These are "most commonly at 20,200 kilometers (12,600 mi), or 20,650 kilometers (12,830 mi), with an orbital period of 12 hours <a href="https://en.wikipedia.org/wiki/List_of_orbits?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01"> \[8] </a>
#
# *   <b> HEO </b> Geocentric orbits above the altitude of geosynchronous orbit (35,786 km or 22,236 mi) <a href="https://en.wikipedia.org/wiki/List_of_orbits?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01"> \[9] </a>
#
# *   <b> GEO </b> It is a circular geosynchronous orbit 35,786 kilometres (22,236 miles) above Earth's equator and following the direction of Earth's rotation <a href="https://en.wikipedia.org/wiki/Geostationary_orbit?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01"> \[10] </a>
#
# *   <b> PO </b> It is one type of satellites in which a satellite passes above or nearly above both poles of the body being orbited (usually a planet such as the Earth <a href="https://en.wikipedia.org/wiki/Polar_orbit?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01"> \[11] </a>
#
# some are shown in the following plot:

# %% [markdown]
# ![](./images/Orbits.png)

# %% [markdown]
# The method  <code>.value_counts()</code> was used to determine the number and occurrence of each orbit in the  column <code>Orbit</code>.

# %%
# Filter Orbit values
mapping = {
    'Polar': 'PO',         
    'SO': 'SSO'        
}
# Apply the mapping to update values in the 'Orbit' column.
df['Orbit'] = df['Orbit'].replace(mapping)

# Apply value_counts on Orbit column
display(df['Orbit'].value_counts())
# Out:
# Orbit
# GTO      32
# LEO      30
# ISS      21
# VLEO     14
# PO       10
# SSO       8
# MEO       3
# ES-L1     1
# HEO       1
# GEO       1
# Name: count, dtype: int64

# %% [markdown]
# ### TASK 3: Calculation of the number and occurence of mission outcome per orbit type

# %% [markdown]
# Occurence can be calculated per orbit type in the following:

# %%
df.value_counts(['Orbit','Mission_Outcome'],sort=False)
# Out:
# Orbit  Mission_Outcome
# ES-L1  True Ocean          1
# GEO    True ASDS           1
# GTO    False ASDS          1
#        None None          11
#        True ASDS          13
#        True Ocean          1
# HEO    True ASDS           1
# ISS    False ASDS          2
#        False Ocean         1
#        False RTLS          1
#        None ASDS           1
#        None None           3
#        True ASDS           5
#        True Ocean          1
#        True RTLS           7
# LEO    None None           2
#        True Ocean          1
#        True RTLS           4
# MEO    None None           1
#        True ASDS           2
# PO     False ASDS          1
#        False Ocean         1
#        None None           1
#        True ASDS           5
#        True Ocean          1
# SSO    None None           1
#        True ASDS           2
#        True RTLS           3
# VLEO   False ASDS          2
#        True ASDS          12
# Name: count, dtype: int64

# %% [markdown]
# The method <code>.value_counts()</code> will be applied to the <code>Mission_Outcome</code> column to determine the number of <code>landing_outcomes</code>, and the result will then be assigned to the variable <code>landing_outcomes</code>.

# %%
# landing_outcomes = values on Outcome column
landing_outcomes = df['Mission_Outcome'].value_counts()
landing_outcomes
# Out:
# Mission_Outcome
# True ASDS      41
# None None      19
# True RTLS      14
# False ASDS      6
# True Ocean      5
# False Ocean     2
# None ASDS       1
# False RTLS      1
# Name: count, dtype: int64

# %% [markdown]
# The following bullet points have been prepared to clarify the designations utilised in representing the outcomes of mission landings:
#
# - **`True Ocean`** represents a mission outcome in which a successful landing was achieved in a designated region of the ocean.
# - **`False Ocean`** represents a mission outcome in which the landing was unsuccessful.
# - **`True RTLS`** represents a mission outcome in which a successful landing was accomplished on a ground pad.
# - **`False RTLS`** represents a mission outcome in which the landing was unsuccessful.
# - **`True ASDS`** represents a mission outcome in which a successful landing was accomplished on a drone ship.
# - **`False ASDS`** represents a mission outcome in which the landing was unsuccessful.
# - **`None ASDS`** and **`None None`** are utilised to denote a failure to land.

# %%
for i,outcome in enumerate(landing_outcomes.keys()):
    print(i,outcome)
# Out:
# 0 True ASDS
# 1 None None
# 2 True RTLS
# 3 False ASDS
# 4 True Ocean
# 5 False Ocean
# 6 None ASDS
# 7 False RTLS

# %% [markdown]
# A set of outcomes where the second stage did not land successfully will be created:

# %%
bad_outcomes=set(landing_outcomes.keys()[[1,3,5,6,7]])
bad_outcomes
# Out:
# {'False ASDS', 'False Ocean', 'False RTLS', 'None ASDS', 'None None'}

# %% [markdown]
# ### TASK 4: Creation of a landing outcome label from Outcome column

# %% [markdown]
# Using the <code>Outcome</code>,  a list will be created where the element is zero if the corresponding  row  in  <code>Outcome</code> is in the set <code>bad_outcome</code> ; otherwise, would be one. Subsequently, it will be assigned to the variable <code>landing_class</code>:

# %%
landing_class=[]
length = len(df['Mission_Outcome'])
for i in range(length):
    if df['Mission_Outcome'].iloc[i] in bad_outcomes:
        landing_class.append(0)
    else:
        landing_class.append(1)

# %% [markdown]
# This variable is utilised as the classification variable representing the outcome of each launch. A value of zero, indicates the  first stage did **not land successfully**; whereas a value of one means  the first stage landed **Successfully**.

# %%
df['Class']=landing_class

# %%
df.sample(5)
# Out:
#     Block Booster_Landing       Date  Flights GridFins  \
# 98    NaN         Success 2020-11-21      NaN      NaN
# 53    5.0         Success 2018-05-11      1.0     True
# 4     1.0      No attempt 2013-03-01      1.0    False
# 77    5.0         Success 2020-01-07      4.0     True
# 34    3.0         Success 2017-06-03      1.0     True
#
#                  Landing_Pad   Latitude Launch_Outcome   Legs  Longitude  \
# 98                       NaN        NaN        Success    NaN        NaN
# 53  5e9e3032383ecb6bb234e7ca  28.608058        Success   True -80.603956
# 4                       None  28.561857        Success  False -80.577366
# 77  5e9e3032383ecb6bb234e7ca  28.561857        Success   True -80.577366
# 34  5e9e3032383ecb267a34e7c7  28.608058        Success   True -80.603956
#
#    Mission_Outcome                                   Payload Reused  \
# 98             NaN  Sentinel-6 Michael Freilich (Jason-CS A)    NaN
# 53       True ASDS                             Bangabandhu-1  False
# 4        None None                              SpaceX CRS-2  False
# 77       True ASDS                                  Starlink   True
# 34       True RTLS                             SpaceX CRS-11  False
#
#     Reused_Count Serial                  date_utc Booster_Version  \
# 98           NaN    NaN                       NaT           F9 B5
# 53           3.0  B1046 2018-05-11 20:14:00+00:00        Falcon 9
# 4            0.0  B0007 2013-03-01 19:10:00+00:00        Falcon 9
# 77           9.0  B1049 2020-01-07 02:19:00+00:00        Falcon 9
# 34           1.0  B1035 2017-06-03 21:07:00+00:00        Falcon 9
#
#           Customer Orbit Payload_Mass          Time (UTC)   Launch_Site  \
# 98            NASA   LEO     1,192 kg 2025-02-19 17:17:08   VAFB SLC-4E
# 53  Bangladesh Gov   GTO       3750.0 2025-02-19 20:14:00    KSC LC-39A
# 4       NASA (CRS)   ISS        677.0 2025-02-19 15:10:00  CCSFS SLC-40
# 77          SpaceX  VLEO      15600.0 2025-02-19 02:19:21  CCSFS SLC-40
# 34      NASA (CRS)   ISS       2708.0 2025-02-19 21:07:00    KSC LC-39A
#
#    Facility Complex  Flight_Number  Class
# 98     VAFB  SLC-4E             99      1
# 53      KSC  LC-39A             54      1
# 4     CCSFS  SLC-40              5      0
# 77    CCSFS  SLC-40             78      1
# 34      KSC  LC-39A             35      1

# %% [markdown]
# The following line of code is to determine  the success rate:

# %%
float(df["Class"].mean())
# Out:
# 0.7603305785123967

# %% [markdown]
# The number and occurence of mission outcome per orbit type can be calculated in the following:

# %%
df.value_counts(['Orbit','Class','Booster_Landing'],sort=False)
# Out:
# Orbit  Class  Booster_Landing
# ES-L1  1      Controlled          1
# GEO    1      Success             1
# GTO    0      Failure             1
#               No attempt         11
#        1      Controlled          1
#               Failure             1
#               No attempt          1
#               Success            17
# HEO    1      Success             1
# ISS    0      Failure             3
#               No attempt          3
#               Precluded           1
#               Uncontrolled        1
#        1      Controlled          1
#               Success            12
# LEO    0      Failure             1
#               No attempt          1
#        1      Controlled          1
#               Failure             2
#               No attempt          1
#               Success            24
# MEO    0      No attempt          1
#        1      Success             2
# PO     0      Failure             1
#               No attempt          1
#               Uncontrolled        1
#        1      Controlled          1
#               No attempt          1
#               Success             5
# SSO    0      No attempt          1
#        1      No attempt          1
#               Success             6
# VLEO   0      Failure             2
#        1      Success            12
# Name: count, dtype: int64

# %% [markdown]
# The dataset shall be exported to **CSV** and **Pickle** files for the subsequent sections.

# %%
# save as CSV file 
csv_file = os.path.join(INTERIM_DATA_DIR, "dataset_part_2.csv")
df.to_csv(csv_file, index=False)

# save as Pickle file
pickle_file= os.path.join(INTERIM_DATA_DIR, 'dataset_part_2.pkl')
df.to_pickle(pickle_file)

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
